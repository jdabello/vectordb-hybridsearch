# %% [markdown]
# # Text and ANN Search on Astra DB (powered by cassandra)
#
# This notebook demonstrates how Astra DB can combine vector similarity search with term search to improve performance, and increase relevance on Generative AI use cases.

# %% [markdown]
# ## Dependencies

# %%
pip install datasets cassandra-driver
# Out:
# Requirement already satisfied: datasets in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (2.14.5)
# Requirement already satisfied: cassandra-driver in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (3.28.0)
# Requirement already satisfied: numpy>=1.17 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from datasets) (13.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from datasets) (2.1.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from datasets) (3.3.0)
# Requirement already satisfied: multiprocess in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from datasets) (3.8.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from datasets) (0.17.3)
# Requirement already satisfied: packaging in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: six>=1.9 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from cassandra-driver) (1.16.0)
# Requirement already satisfied: geomet<0.3,>=0.1 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from cassandra-driver) (0.2.1.post1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from aiohttp->datasets) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: click in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from geomet<0.3,>=0.1->cassandra-driver) (8.1.7)
# Requirement already satisfied: filelock in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.12.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/juan.abello/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Astra DB Setup

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider

# %%
import os
from getpass import getpass

try:
    from google.colab import files
    IS_COLAB = True
except ModuleNotFoundError:
    IS_COLAB = False

# %%
# Your database's Secure Connect Bundle zip file is needed:
if IS_COLAB:
    print('Please upload your Secure Connect Bundle zipfile: ')
    uploaded = files.upload()
    if uploaded:
        astraBundleFileTitle = list(uploaded.keys())[0]
        ASTRA_DB_SECURE_BUNDLE_PATH = os.path.join(os.getcwd(), astraBundleFileTitle)
    else:
        raise ValueError(
            'Cannot proceed without Secure Connect Bundle. Please re-run the cell.'
        )
else:
    # you are running a local-jupyter notebook:
    ASTRA_DB_SECURE_BUNDLE_PATH = input("Please provide the full path to your Secure Connect Bundle zipfile: ")

ASTRA_DB_APPLICATION_TOKEN = getpass("Please provide your Database Token ('AstraCS:...' string): ")
ASTRA_DB_KEYSPACE = input("Please provide the Keyspace name for your Database: ")

# %%
# Don't mind the "Closing connection" error after "downgrading protocol..." messages,
# it is really just a warning: the connection will work smoothly.
cluster = Cluster(
    cloud={
        "secure_connect_bundle": ASTRA_DB_SECURE_BUNDLE_PATH,
    },
    auth_provider=PlainTextAuthProvider(
        "token",
        ASTRA_DB_APPLICATION_TOKEN,
    ),
)

session = cluster.connect()
keyspace = ASTRA_DB_KEYSPACE

# %% [markdown]
# ## Load Dataset
#
# For this example we are going to be using a variation of the [yahoo_answers dataset](https://huggingface.co/datasets/yahoo_answers_topics/viewer/yahoo_answers_topics/train) from huggingface. For demonstration purposes, we included the label for topic (instead of its id), so that we can use term based search to filter our queries. This dataset has over 1,000,000 answers so it's great for demonstrating Astra DB's performance, scalability, and to leverage filtering capabilities with hybrid search.

# %%
from datasets import load_dataset
dataset = load_dataset("jdabello/yahoo_answers_topics", split="train")
dataset
# Out:
# Dataset({
#     features: ['id', 'topic', 'question_title', 'question_content', 'best_answer'],
#     num_rows: 1400000
# })

# %% [markdown]
# Lets inspect one record.

# %%
dataset[0]
# Out:
# {'id': 0,
#  'topic': 'Computers & Internet',
#  'question_title': "why doesn't an optical mouse work on a glass table?",
#  'question_content': 'or even on some surfaces?',
#  'best_answer': 'Optical mice use an LED and a camera to rapidly capture images of the surface beneath the mouse.  The infomation from the camera is analyzed by a DSP (Digital Signal Processor) and used to detect imperfections in the underlying surface and determine motion. Some materials, such as glass, mirrors or other very shiny, uniform surfaces interfere with the ability of the DSP to accurately analyze the surface beneath the mouse.  \\nSince glass is transparent and very uniform, the mouse is unable to pick up enough imperfections in the underlying surface to determine motion.  Mirrored surfaces are also a problem, since they constantly reflect back the same image, causing the DSP not to recognize motion properly. When the system is unable to see surface changes associated with movement, the mouse will not work properly.'}

# %% [markdown]
# ## LLM Setup

# %%
OPENAI_API_KEY = getpass("Please enter your OpenAI API Key: ")

# %%
import openai

openai.api_key = OPENAI_API_KEY

# %% [markdown]
# The yahoo answers dataset, has 2 separate columns for the Question Title, and the Question Content. For this excercise we are concatenating those into a single column that we will call Question. For demonstration purposes, we are going to get the embedding of the first question, and get the number of dimensions for that vector. This is needed to create the table.

# %%
embedding_model_name = "text-embedding-ada-002"

result = openai.Embedding.create(
    input=f"{dataset[0]['question_title']}. {'question_content'}",
    engine=embedding_model_name,
)
result
# Out:
# <OpenAIObject list at 0x28d9502f0> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "object": "embedding",
#       "index": 0,
#       "embedding": [
#         0.008803000673651695,
#         -0.01650131121277809,
#         0.0021489679347723722,
#         -0.02678874135017395,
#         -0.0017424763645976782,
#         0.01860022358596325,
#         -0.023888928815722466,
#         -0.02329515665769577,
#         -0.03457680717110634,
#         -0.02220427617430687,
#         0.015451855957508087,
#         0.004460187163203955,
#         -0.013877672143280506,
#         -0.01717793568968773,
#         -0.017868366092443466,
#         0.02045057900249958,
#         0.010149342939257622,
#         0.02054724097251892,
#         0.013856959529221058,
#         -0.015879923477768898,
#         -0.03532247245311737,
#         0.009548666886985302,
#         0.008913470432162285,
#         -0.00653838599100709,
#         -0.015258535742759705,
#         -0.005633920896798372,
#         0.004498160909861326,
#         -0.03093132935464382,
#         -0.006162100937217474,
#         0.028694331645965576,
#         0.027603449299931526,
#         -4.379924575914629e-05,
#         -0.04208870232105255,
#         -0.005951519124209881,
#         -0.031428441405296326,
#         0.009748891927301884,
#         -0.0010252906940877438,
#         -0.011785664595663548,
#         0.010687879286706448,
#         -0.03477012738585472,
#         0.0018175608711317182,
#         -0.007083826698362827,
#         -0.01629418320953846,
#         0.017564576119184494,
#         -0.018862588331103325,
#         0.04070783779025078,
#         0.007484277244657278,
#         0.008658010512590408,
#         -0.0024596620351076126,
#         0.008941087871789932,
#         0.01235872320830822,
#         0.018199773505330086,
#         -0.035267237573862076,
#         -0.02688540145754814,
#         0.019553018733859062,
#         -0.012068741954863071,
#         0.0122965844348073,
#         -0.009804126806557178,
#         0.019111143425107002,
#         -0.011454258114099503,
#         0.015313769690692425,
#         0.009907691739499569,
#         -0.018890203908085823,
#         0.0003844840102829039,
#         -0.00826446432620287,
#         -0.003079324262216687,
#         -0.019718723371624947,
#         0.0186140313744545,
#         -0.022549491375684738,
#         -0.013062963262200356,
#         0.004601725842803717,
#         0.043800972402095795,
#         0.009155121631920338,
#         0.006762776058167219,
#         0.022687578573822975,
#         0.005792719777673483,
#         -0.021928103640675545,
#         0.005613207817077637,
#         0.007857110351324081,
#         -0.010246003046631813,
#         0.016584163531661034,
#         -0.014153844676911831,
#         -0.019097333773970604,
#         -0.006296734791249037,
#         -0.012103263288736343,
#         -0.011067616753280163,
#         -0.012966303154826164,
#         0.002747917314991355,
#         0.01959444396197796,
#         0.02778296172618866,
#         0.022259511053562164,
#         -0.012448479421436787,
#         -0.027644876390695572,
#         -0.0180340688675642,
#         -0.011661387048661709,
#         -0.019428741186857224,
#         -0.00983864814043045,
#         -0.027534406632184982
#       ]
#     }
#   ],
#   "model": "text-embedding-ada-002-v2",
#   "usage": {
#     "prompt_tokens": 14,
#     "total_tokens": 14
#   }
# }

# %%
#Let's get the number of dimensions for our embedding
len(result.data[0].embedding)
# Out:
# 1536

# %%
# Run this to drop the table and indexes before starting over
session.execute(f"DROP TABLE IF EXISTS {ASTRA_DB_KEYSPACE}.yahoo_answers")

# %% [markdown]
# Now we are going to create our table. We will include the id of the answer, the topic, the Question (concatenated title, and content), the best answer, and the embedding of the question. That's what we will use for the ANN search. We now know that the embedding model we are using generates an embedding with 1536 dimensions.

# %%
mktable_cql = f"""CREATE TABLE {ASTRA_DB_KEYSPACE}.yahoo_answers (
answer_id int PRIMARY KEY,
topic text,
question text,
best_answer text,
question_embedding vector<float, 1536>
);
"""
session.execute(mktable_cql)

# %%
session.execute(f"""CREATE CUSTOM INDEX ON {ASTRA_DB_KEYSPACE}.yahoo_answers(question_embedding)
                USING 'org.apache.cassandra.index.sai.StorageAttachedIndex'
                WITH OPTIONS = {{ 'similarity_function': 'dot_product' }}""")

# %%
session.execute(f"""
    CREATE CUSTOM INDEX ON {ASTRA_DB_KEYSPACE}.yahoo_answers(topic)
    USING 'org.apache.cassandra.index.sai.StorageAttachedIndex'
    WITH OPTIONS = {{
    'index_analyzer': '{{
    "tokenizer" : {{"name" : "standard"}},
    "filters" : [{{"name" : "porterstem"}},{{"name" : "lowercase",	"args": {{}}}}]
    }}'}};""")

# %% [markdown]
# We created the embedding for a single record. Now let's do it for 50,000 questions. Note that you can slice the dataset to whatever size you want to test out. This process takes around 8 minutes. There are rate limits in place.

# %%
subset_train_data = dataset.select(range(50000))

# %%
embedding_model_name = "text-embedding-ada-002"

def get_embedding(input):
    embeddings=[]
    if(len(input)>=0):
        result = openai.Embedding.create(
            input=input,
            engine=embedding_model_name,
        )
        for result_data in result.data:
            embeddings.append(result_data.embedding)
    return embeddings

# %%
embedding_params = []


input=[]
for row in subset_train_data:
    input.append(f"{row['question_title']}. {row['question_content']}")
    if len(input) % 2000 == 0:  #sending batches of 2000 questions
        embedding_params=embedding_params+get_embedding(input)
        print(f"{len(embedding_params)} rows processed.")
        input=[]
embedding_params=embedding_params+get_embedding(input)
print(f"{len(embedding_params)} rows processed.")
# Out:
# 2000 rows processed.
# 4000 rows processed.
# 6000 rows processed.
# 8000 rows processed.
# 10000 rows processed.
# 12000 rows processed.
# 14000 rows processed.
# 16000 rows processed.
# 18000 rows processed.
# 20000 rows processed.
# 22000 rows processed.
# 24000 rows processed.
# 26000 rows processed.
# 28000 rows processed.
# 30000 rows processed.
# 32000 rows processed.
# 34000 rows processed.
# 36000 rows processed.
# 38000 rows processed.
# 40000 rows processed.
# 42000 rows processed.
# 44000 rows processed.
# 46000 rows processed.
# 48000 rows processed.
# 50000 rows processed.
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /Users/juan.abello/Documents/Datastax/vectordb-hybridsearch/notebooks/hybrid-search-on-cassandra.ipynb Cell 27 line 1
#       <a href='vscode-notebook-cell:/Users/juan.abello/Documents/Datastax/vectordb-hybridsearch/notebooks/hybrid-search-on-cassandra.ipynb#X50sZmlsZQ%3D%3D?line=8'>9</a>         print(f"{len(embedding_params)} rows processed.")
#      <a href='vscode-notebook-cell:/Users/juan.abello/Documents/Datastax/vectordb-hybridsearch/notebooks/hybrid-search-on-cassandra.ipynb#X50sZmlsZQ%3D%3D?line=9'>10</a>         input=[]
# ---> <a href='vscode-notebook-cell:/Users/juan.abello/Documents/Datastax/vectordb-hybridsearch/notebooks/hybrid-search-on-cassandra.ipynb#X50sZmlsZQ%3D%3D?line=10'>11</a> embedding_params=embedding_params+get_embedding(input)
#      <a href='vscode-notebook-cell:/Users/juan.abello/Documents/Datastax/vectordb-hybridsearch/notebooks/hybrid-search-on-cassandra.ipynb#X50sZmlsZQ%3D%3D?line=11'>12</a> print(f"{len(embedding_params)} rows processed.")
#
# /Users/juan.abello/Documents/Datastax/vectordb-hybridsearch/notebooks/hybrid-search-on-cassandra.ipynb Cell 27 line 6
#       <a href='vscode-notebook-cell:/Users/juan.abello/Documents/Datastax/vectordb-hybridsearch/notebooks/hybrid-search-on-cassandra.ipynb#X50sZmlsZQ%3D%3D?line=3'>4</a> embeddings=[]
#       <a href='vscode-notebook-cell:/Users/juan.abello/Documents/Datastax/vectordb-hybridsearch/notebooks/hybrid-search-on-cassandra.ipynb#X50sZmlsZQ%3D%3D?line=4'>5</a> if(len(input)>=0):
# ----> <a href='vscode-notebook-cell:/Users/juan.abello/Documents/Datastax/vectordb-hybridsearch/notebooks/hybrid-search-on-cassandra.ipynb#X50sZmlsZQ%3D%3D?line=5'>6</a>     result = openai.Embedding.create(
#       <a href='vscode-notebook-cell:/Users/juan.abello/Documents/Datastax/vectordb-hybridsearch/notebooks/hybrid-search-on-cassandra.ipynb#X50sZmlsZQ%3D%3D?line=6'>7</a>         input=input,
#       <a href='vscode-notebook-cell:/Users/juan.abello/Documents/Datastax/vectordb-hybridsearch/notebooks/hybrid-search-on-cassandra.ipynb#X50sZmlsZQ%3D%3D?line=7'>8</a>         engine=embedding_model_name,
#       <a href='vscode-notebook-cell:/Users/juan.abello/Documents/Datastax/vectordb-hybridsearch/notebooks/hybrid-search-on-cassandra.ipynb#X50sZmlsZQ%3D%3D?line=8'>9</a>     )
#      <a href='vscode-notebook-cell:/Users/juan.abello/Documents/Datastax/vectordb-hybridsearch/notebooks/hybrid-search-on-cassandra.ipynb#X50sZmlsZQ%3D%3D?line=9'>10</a>     for result_data in result.data:
#      <a href='vscode-notebook-cell:/Users/juan.abello/Documents/Datastax/vectordb-hybridsearch/notebooks/hybrid-search-on-cassandra.ipynb#X50sZmlsZQ%3D%3D?line=10'>11</a>         embeddings.append(result_data.embedding)
#
# File ~/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages/openai/api_resources/embedding.py:33, in Embedding.create(cls, *args, **kwargs)
#      31 while True:
#      32     try:
# ---> 33         response = super().create(*args, **kwargs)
#      35         # If a user specifies base64, we'll just return the encoded string.
#      36         # This is only for the default case.
#      37         if not user_provided_encoding_format:
#
# File ~/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages/openai/api_requestor.py:298, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#    (...)
#     296         request_timeout=request_timeout,
#     297     )
# --> 298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File ~/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages/openai/api_requestor.py:700, in APIRequestor._interpret_response(self, result, stream)
#     692     return (
#     693         self._interpret_response_line(
#     694             line, result.status_code, result.headers, stream=True
#     695         )
#     696         for line in parse_stream(result.iter_lines())
#     697     ), True
#     698 else:
#     699     return (
# --> 700         self._interpret_response_line(
#     701             result.content.decode("utf-8"),
#     702             result.status_code,
#     703             result.headers,
#     704             stream=False,
#     705         ),
#     706         False,
#     707     )
#
# File ~/Documents/Datastax/bank-assistant-bot/venv/lib/python3.11/site-packages/openai/api_requestor.py:765, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     763 stream_error = stream and "error" in resp.data
#     764 if stream_error or not 200 <= rcode < 300:
# --> 765     raise self.handle_error_response(
#     766         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     767     )
#     768 return resp
#
# InvalidRequestError: '$.input' is invalid. Please check the API reference: https://platform.openai.com/docs/api-reference.

# %%
params_list = []
i=0
for row in subset_train_data:
    params_list.append((row['id'],row['best_answer'],f"{row['question_title']}. {row['question_content']}",embedding_params[i], row['topic']))
    i=i+1

# %%
from cassandra.concurrent import execute_concurrent_with_args
request = session.prepare(
                    f"""
                INSERT INTO {ASTRA_DB_KEYSPACE}.yahoo_answers
                (answer_id, best_answer, question, question_embedding, topic)
                VALUES (?, ?, ?, ?, ?)
                """
)
execute_concurrent_with_args(session, request, params_list)
# Out:
# [ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2b2b10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2b3790>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2d5ed0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2d6c90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2b1b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c30f9d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c30fb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2b2550>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2b1bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2b2250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2b22d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2b3390>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2d5950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2d5f10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2b3810>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2d5990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2b1590>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2b1e90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c325010>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2d5250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2b2f10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2d6990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2d6210>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2b37d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2b1810>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c319e50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2dc950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2d7410>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2dd890>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2d7390>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2dcc10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2ded50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c31b8d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2dcdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2dce10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2e9290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2d5450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2e9210>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2df290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2df7d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2e9cd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2dc3d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2e87d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2eacd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2dfd10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2e9790>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2e8250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2ea550>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2f4690>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2eac90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2eb1d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c305490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2f4bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2dd310>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c305450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2ffe90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2f50d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2ea210>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2f4c10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2fc090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2f6910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2f6090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2f6b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2f6ad0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2ea750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2fcad0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2f6610>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2f7b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2f5b10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c30d650>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2fef50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2fd590>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2fe510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c30d810>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2fe010>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2fdf90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2ffcd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2ffa10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2fea50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c305f10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c304f50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2ff450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2f7590>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c307e50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c307450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c307990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c306ed0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3059d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c30d310>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c30c950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c30ff50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c30cc10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c2f7050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c306410>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c30db90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c306950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c313910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c30c390>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c324a50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3069d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c30f790>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3115d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c310650>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c327150>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3194d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c310c50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c33aad0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c313050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c312710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c319950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3275d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c311150>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c311a10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c30ed50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3307d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c31bcd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3182d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c332250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c312bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c30dd90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c324a90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c326890>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c325310>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c331950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c31a650>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c324e50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c311e50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c313490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c31af50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c31bd10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c324410>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c310350>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c31b850>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c324590>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3386d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3259d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c326450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c318310>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c318750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c31a210>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c31b3d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c313dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38
),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3fef90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4064d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c407750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c407710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c406e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c407b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3fc710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c408490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3eb0d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c408910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3eb4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c409210>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3ebdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c40a910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c40b1d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c406e50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4072d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c411190>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c412c50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4057d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c421150>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3fdd90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c40b650>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c409e50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c410910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c42d090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c40abd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c3fe610>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c423a90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c405390>),
# ...
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4a8d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4a1890>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4a88d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4a3110>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4b4bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4b5090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4aa510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4a9210>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c0510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4aa0d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ab890>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c0a50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4a9710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4b5a10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4aaed0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4b4710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4abe10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4b7750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c1810>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c42d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4b6850>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4a9bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c0550>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c3410>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4b63d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c3890>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4b5510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4b7ed0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c0f10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c1d10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c26d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c1390>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4aaa10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c3050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ab390>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4b7b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c2b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c4290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4b71d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c2250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4b4250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c4b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c6810>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c7290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c5f50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c5610>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c5010>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c4710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c3910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c7750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c46d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c63d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c7a90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4cd390>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c7c10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4cd3d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4c6c90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4cd910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4cc610>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4cca50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4cebd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4cf950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4cca10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4cf4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ce2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4d9ed0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4cefd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4d9f10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4dad90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4d87d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e2190>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4dbed0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4d9590>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4da410>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4cfe50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ce690>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4dabd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e0e90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4d8c50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e0a90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4db750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e0a50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4db290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4d9a90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e2210>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e04d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e2b10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e1890>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e3450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e2690>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e2e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e1450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e1d50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ec390>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ecd50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e2fd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4e3950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ed690>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4edb10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ec890>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ed1d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ee090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ee810>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4f8b10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ee4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4f9d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ef750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4f8650>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ee990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ef2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4f8e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4f8690>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4f9450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4f9950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fa710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fa590>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fbf10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fb5d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fa290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fe5d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fb050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fc950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fac10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fc410>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fd790>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fcd90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fdad0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c60cc50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fd310>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ffdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fed90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c60e890>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fe110>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fdc90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4fea90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c60f690>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c60c250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c611950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ff390>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c60f710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c60da10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c612250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c4ff890>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c610f10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c60e390>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c60cc10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c60f990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c60d590>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c60f250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c60ded0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c611910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c613a10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c6109d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c60ed10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c6120d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c6134d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c611d50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c60fb50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c613050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c612710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x38c611350>),
#  ...]

# %% [markdown]
# ## ANN Search
#
# We are running an ambiguous query on purpose to show how the relevance would be improved by adding a filter on the topic as well. We'll start with just ANN search.

# %%
from cassandra.query import SimpleStatement
question = 'Is apple good?'

result = openai.Embedding.create(
    input=question,
    engine=embedding_model_name,
)
embedding=result.data[0].embedding

query = SimpleStatement(
    f"""
    SELECT question, best_answer
    FROM {ASTRA_DB_KEYSPACE}.yahoo_answers
    ORDER BY question_embedding ANN OF {embedding} LIMIT 10;
    """
    )

results = session.execute(query)
top_answers = results._current_rows

for row in top_answers:
  print(f"""{row.question}, {row.best_answer}\n""")
# Out:
# Which is better,a apple or a peach?. , PEACHES!
#
# which is better - apple or orange ?. , I think that apples have many uses.  I've used them in a chicken stir-fry, pie, with tuna salad or chicken salad, on a spinach salad, baked, fried, peeled, sliced, as a garnish.\n\nI've also consumed them in juice, cider, hard cider, applesauce, and many types of deserts.\n\nApples are also more exciting because there are so many distinct varieties.  I like Gala apples the best.\n\nOranges are great, but other than for eating them plain, drinking orange juice, or using a little orange zest in a recipe, I don't have as many uses for them.  Plus, the peel makes them more time-consuming to eat.
#
# Are iPods good or bad?. , Good. All your music and videos in your palm.
#
# Why is the apple on Apple's (the IT co.) bitten??. , It's a forbiden fruit- tempting users to try it (Heaven's own ;). Inspiring your imagination (Jobs was/is one big marketing guy)\n+ One of the logos have had the "a" from apple fitting right over the apple.\n\n\nYou can find more about Apple's logo & history here:\nhttp://en.wikipedia.org/wiki/Apple_computer#Logo
#
# dell or apple?. , I used to work for Dell, and in my honest opinion, Dell would be the better way to go.  When you buy a Dell, you get a lower price because it's direct from the manufactuer.  Plus, there customer service is a customer-comes-first focus, so you get top rated care, but remember it's only for hardware issues, not how-to-use-my-computer because-I'm-new issues.\n\nI've never tried apple, but I want to.  But I own a Dell, I have a dell axim and dell dj, and I Always get good service and a good price.
#
# Is Apple Computers conceited?. They boast about themselves alot. Do they're products deserve the respect., Well, their marketing position has been 'cutting edge', 'sophiticated' and borderline elitist for some time.  Their products (especially computers) have been priced higher than comperable PCs (in terms of processing power, so as to not turn this into Windows vs. MacOS diatribe).  This price difference was to maintain this elite status.  So yes, in that way they are concieted.  However, they are a larger company than Sony (by market capitalization), despite the fact Sony releases more new products in a month than Apple does in a year, so I guess they've earned some bragging rights.
#
# what is apple's mission statement?. , Q: What is Apple's mission statement?\nA: Apple ignited the personal computer revolution in the 1970s with the Apple II and reinvented the personal computer in the 1980s with the Macintosh. Apple is committed to bringing the best personal computing experience to students, educators, creative professionals and consumers around the world through its innovative hardware, software and Internet offerings.\n\nWhat is Apple's mission statement?\nApple ignited the personal computer revolution in the 1970s with the Apple II and reinvented the personal computer in the 1980s with the Macintosh. Apple is widely recognized for its innovative and award-winning Mac desktop and notebook computers, OS X operating system, and iLife digital lifestyle and professional applications. Apple is also leading the digital music revolution with its market-leading iPod line of portable music players and iTunes online music store.
#
# Do tyou think Apple did a right move with Mactels?. Or the switch to Intel it's a bad movement?, It was done for marketing only.  I don't see it as either good or bad.  Most likely will be a bumpy ride for the users for a few years, but will end up being a basic "wash out" as far as any improvements.
#
# Is Dell a good brand of computer?. , It's as good as most others.  I don't know where they got the reputation for quality - they're assembled from the same parts that any brand name computer has.   I'm not crazy about their tech support which requires you to chat with an artificial intelligence before they elevate your problem to something that should be handled by a human.\n\nThe one thing Dell has going for it is the Wallmart-like stranglehold on it's manufacturers, which keeps their prices very cheap.\n\nThe worst thing I can say about Dell is that you won't be able to buy a computer with an AMD CPU, which means, for the time being, you won't be able to get the fastest computers.  However, you'll be able to save enough money that you might get more for your money if you're not going for a top-of-the-line machine.\n\nBeware of the add-ons if you do go with Dell or most brands, for that matter.  That's where they get you.  The warranty, the leather case, the printer, etc.  Most of those things can be purchased for less money elsewhere - especially the RAM.  They always give you the bare minimum RAM so that the base price looks low and then they gouge you to upgrade to more RAM.  If you want to save a bundle, just get your RAM from another store (search pricewatch, that's a good start) because it'll be much cheaper and RAM's super easy to pop in.
#
# is the internet on an apple quicker than a Dell?. , As a major Mac user and Fan of Apple. I regret to say NO.\n\nThat does not mean the machine is inherently slow, it has a lot to do with how the software interacts and how the website is written.\n\nA Dell uses Microsoft Windows. Internet Explorer is built into the OS. A Mac uses afari as a browser. While components are built in, it is still a separate application.\n\nSafari is one of the few Standards compliant browsers. That makes it very good at following the rules for HTML CSS, etc. But it also means many sites can confuse it and even break it when you visit and not work properly.\n\nThis and some other issues related to network use, makes browsing on the Mac slightly slower on all pages, and noticeable slower on a few poorly coded pages.\n\nThis slight performance gap will son be remedied with updates to the OS and hardware in upcoming weeks.\n\nSafari has come a long way from version 1.0 and is oftn faster than IE in rendering tests, but in the real world most people report surfing with a PC feels snappier than a Mac.

# %% [markdown]
# There are some answers that reference Apple's (the technology company headquartered in California), but the top results are actually referencing the fruit. Relevance can be improved by leveraging hybrid search and filtering by topic.

# %%
from cassandra.query import SimpleStatement
question = 'Is apple good?'

result = openai.Embedding.create(
    input=question,
    engine=embedding_model_name,
)
embedding=result.data[0].embedding

query = SimpleStatement(
    f"""
    SELECT question, best_answer
    FROM {ASTRA_DB_KEYSPACE}.yahoo_answers
    WHERE topic : 'computers'
    ORDER BY question_embedding ANN OF {embedding} LIMIT 10;
    """
    )

results = session.execute(query)
top_answers = results._current_rows

for row in top_answers:
  print(f"""{row.question}, {row.best_answer}\n""")
# Out:
# Why is the apple on Apple's (the IT co.) bitten??. , It's a forbiden fruit- tempting users to try it (Heaven's own ;). Inspiring your imagination (Jobs was/is one big marketing guy)\n+ One of the logos have had the "a" from apple fitting right over the apple.\n\n\nYou can find more about Apple's logo & history here:\nhttp://en.wikipedia.org/wiki/Apple_computer#Logo
#
# dell or apple?. , I used to work for Dell, and in my honest opinion, Dell would be the better way to go.  When you buy a Dell, you get a lower price because it's direct from the manufactuer.  Plus, there customer service is a customer-comes-first focus, so you get top rated care, but remember it's only for hardware issues, not how-to-use-my-computer because-I'm-new issues.\n\nI've never tried apple, but I want to.  But I own a Dell, I have a dell axim and dell dj, and I Always get good service and a good price.
#
# Is Apple Computers conceited?. They boast about themselves alot. Do they're products deserve the respect., Well, their marketing position has been 'cutting edge', 'sophiticated' and borderline elitist for some time.  Their products (especially computers) have been priced higher than comperable PCs (in terms of processing power, so as to not turn this into Windows vs. MacOS diatribe).  This price difference was to maintain this elite status.  So yes, in that way they are concieted.  However, they are a larger company than Sony (by market capitalization), despite the fact Sony releases more new products in a month than Apple does in a year, so I guess they've earned some bragging rights.
#
# Do tyou think Apple did a right move with Mactels?. Or the switch to Intel it's a bad movement?, It was done for marketing only.  I don't see it as either good or bad.  Most likely will be a bumpy ride for the users for a few years, but will end up being a basic "wash out" as far as any improvements.
#
# Is Dell a good brand of computer?. , It's as good as most others.  I don't know where they got the reputation for quality - they're assembled from the same parts that any brand name computer has.   I'm not crazy about their tech support which requires you to chat with an artificial intelligence before they elevate your problem to something that should be handled by a human.\n\nThe one thing Dell has going for it is the Wallmart-like stranglehold on it's manufacturers, which keeps their prices very cheap.\n\nThe worst thing I can say about Dell is that you won't be able to buy a computer with an AMD CPU, which means, for the time being, you won't be able to get the fastest computers.  However, you'll be able to save enough money that you might get more for your money if you're not going for a top-of-the-line machine.\n\nBeware of the add-ons if you do go with Dell or most brands, for that matter.  That's where they get you.  The warranty, the leather case, the printer, etc.  Most of those things can be purchased for less money elsewhere - especially the RAM.  They always give you the bare minimum RAM so that the base price looks low and then they gouge you to upgrade to more RAM.  If you want to save a bundle, just get your RAM from another store (search pricewatch, that's a good start) because it'll be much cheaper and RAM's super easy to pop in.
#
# is the internet on an apple quicker than a Dell?. , As a major Mac user and Fan of Apple. I regret to say NO.\n\nThat does not mean the machine is inherently slow, it has a lot to do with how the software interacts and how the website is written.\n\nA Dell uses Microsoft Windows. Internet Explorer is built into the OS. A Mac uses afari as a browser. While components are built in, it is still a separate application.\n\nSafari is one of the few Standards compliant browsers. That makes it very good at following the rules for HTML CSS, etc. But it also means many sites can confuse it and even break it when you visit and not work properly.\n\nThis and some other issues related to network use, makes browsing on the Mac slightly slower on all pages, and noticeable slower on a few poorly coded pages.\n\nThis slight performance gap will son be remedied with updates to the OS and hardware in upcoming weeks.\n\nSafari has come a long way from version 1.0 and is oftn faster than IE in rendering tests, but in the real world most people report surfing with a PC feels snappier than a Mac.
#
# How do you get a job at Apple?. , Hey!  Apple is a really cool corporation, I'm happy your picking up interest in such a cool and innovate company.\n\nhttp://jobs.apple.com/ is a web page designed for jobs at apple.\n\nThey hire at a whole range of experience levels.  Good luck!\n\nTony
#
# Macintosh or Microsoft?. Which do you prefer?, I definitely prefer Mac OS X over Windows. It is more stable, has virtually no viruses or spyware and more pleasant to use.
#
# Who makes the best laptops?. , No. 1 Dell\nNo. 2 Toshiba
#
# Does Toshiba have good laptops?. , No.  The last Toshiba I had, the damn screws literally fell out of it.  YA the screws in the bottom holding the bottom of it started to come out.  (3 or 4 went missing before I noticed it.)  \n\nI have never had that problem with any other laptop.  Toshiba refused to send out the screws that I needed.  Their excuse was that they didn't "stock screws".  My argument was that I shouldn't have to send a laptop in for service when all I need is a damn screw.\n\nI was really pissed that they couldn't help me.  I went to the hardware store and bought my own damn small screws.\n\nThe moral of this story is:  Screw Toshiba before they screw you!\n\nNo kidding.  Sony's tech support isn't very good in my opinion.  I called them for hardware problems where I knew the laptop had to be sent in to be fixed BECAUSE IT WOULDN'T POWER ON AT ALL, and they made me do all the things I had already told them I'd done before they would move through the process.   The people that actually replaced the hardware were nice and seemed to be knowledgable.  I talked with them because they had a question before finishing the job.\n\nGateway and Dell laptops might be pretty good.  I really like HP laptops though, especially the ones with the AMD processors.  If you get a laptop be sure to go with one that has a powerful video card so that if you do decide to play games on it, you won't be severely limited by the dinky graphics card in most laptops.  ATI 9700, ATI9800 or some of the geforce video cards are really good in these newer laptops.  They cost a little more, but give you a lot more power when it comes to graphics performance.\n\nHP seems to be a good balance between durability, power, cost, and reliability.  My wife's HP laptop has worked like a champ and is a pretty good all around computer for games, office, internet, and other applications.
